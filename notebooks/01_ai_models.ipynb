# %%
import pandas as pd

data_path = "../data/culture_hackathon_data_only.xlsx"

events = pd.read_excel(data_path, sheet_name="events_synthetic")
attendance = pd.read_excel(data_path, sheet_name="attendance_synthetic")
audience = pd.read_excel(data_path, sheet_name="audience_synthetic")
institutions = pd.read_excel(data_path, sheet_name="institutions_official")

print(events.shape)
print(attendance.shape)
print(audience.shape)
print(institutions.shape)
# Out:
# (225, 13)
# (225, 8)
# (5000, 9)
# (19, 16)
