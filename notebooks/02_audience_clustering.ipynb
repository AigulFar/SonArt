# %% [markdown]
# # 02. Кластеризация аудитории

# %%
import sys
from pathlib import Path
sys.path.append(str(Path("../AI_section").resolve()))
from ai_predict import load_audience,cluster_audience,cluster_summary,plot_clusters
audience=load_audience()
clustered,model=cluster_audience(audience,min_cluster_size=100)
display(cluster_summary(clustered))

# %%
plot_clusters(clustered,model)

# %% [markdown]
# "`cluster = -1` означает точки, которые HDBSCAN не смог уверенно отнести к группе. Остальные группы можно описать по возрасту, частоте посещений, вовлечённости и любимому типу мероприятий.
